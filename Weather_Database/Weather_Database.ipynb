# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
# Create 2000 random lats and longs
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create list of lat longs
coordinates = list(lat_lngs)

# %%
# Get nearest cities of each lat/lng pair and add to a list
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # Add unique cities to cities=[]
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 745

# %%
# Call the OpenWeatherMap API

# List for city data
city_data = []
# Print for logging data retrieval
print('Beginning Data Retrieval    ')
print('____________________________')

# Add Counters to know how many cities data has been pulled for
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ____________________________

# %%
# Loop through the cities list
for i, city in enumerate(cities):
    # Group cities in sets of 100 to logging info
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(10)
    
    # Create URL for calling weather data
    url = "https://api.openweathermap.org/data/2.5/weather?q="
    city_url = url + city.replace(' ', '+') + '&appid=' + weather_api_key + '&units=imperial'
    print(city_url)
    
    # Log URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Increase record count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=labuhan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 1 | labuhan
# https://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 1 | mahebourg
# https://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=wum&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 1 | wum
# https://api.openweathermap.org/data/2.5/weather?q=albany&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 1 | albany
# https://api.openweathermap.org/data/2.5/weather?q=sur&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 1 | sur
# https://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 1 | hermanus
# https://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 1 | palabuhanratu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=berdigestyakh&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 1 | berdigestyakh
# https://api.openweathermap.org/data/2.5/weather?q=manono&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 1 | manono
# https://api.openweathermap.org/data/2.5/weather?q=dunedin&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 1 | dunedin
# https://api.openweathermap.org/data/2.5/weather?q=busselton&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 1 | busselton
# https://api.openweathermap.org/data/2.5/weather?q=atuona&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 1 | atuona
# https://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 1 | georgetown
# https://api.openweathermap.org/data/2.5/weather?q=bilma&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 1 | bilma
# https://api.openweathermap.org/data/2.5/weather?q=mataura&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 1 | mataura
# https://api.openweathermap.org/data/2.5/weather?q=luderitz&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 1 | luderitz
# https://api.openweathermap.org/data/2.5/weather?q=trogir&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 1 | trogir
# https://api.openweathermap.org/data/2.5/weather?q=ulladulla&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 1 | ulladulla
# https://api.openweathermap.org/data/2.5/weather?q=mandalgovi&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 1 | mandalgovi
# https://api.openweathermap.org/data/2.5/weather?q=korla&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 1 | korla
# https://api.openweathermap.org/data/2.5/weather?q=east+london&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?q=halalo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 1 | halalo
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=black+river&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 1 | black river
# https://api.openweathermap.org/data/2.5/weather?q=palmer&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 1 | palmer
# https://api.openweathermap.org/data/2.5/weather?q=dargaville&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 1 | dargaville
# https://api.openweathermap.org/data/2.5/weather?q=norman+wells&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 1 | norman wells
# https://api.openweathermap.org/data/2.5/weather?q=sechura&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 1 | sechura
# https://api.openweathermap.org/data/2.5/weather?q=leningradskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 1 | leningradskiy
# https://api.openweathermap.org/data/2.5/weather?q=clyde+river&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 1 | clyde river
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 1 | ushuaia
# https://api.openweathermap.org/data/2.5/weather?q=lebu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 1 | lebu
# https://api.openweathermap.org/data/2.5/weather?q=faanui&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 1 | faanui
# https://api.openweathermap.org/data/2.5/weather?q=shimoda&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 1 | shimoda
# https://api.openweathermap.org/data/2.5/weather?q=kendari&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 1 | kendari
# https://api.openweathermap.org/data/2.5/weather?q=port+alfred&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 1 | port alfred
# https://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 1 | longyearbyen
# https://api.openweathermap.org/data/2.5/weather?q=hobart&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 1 | hobart
# https://api.openweathermap.org/data/2.5/weather?q=kibala&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 1 | kibala
# https://api.openweathermap.org/data/2.5/weather?q=marcona&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 1 | marcona
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=dharchula&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 1 | dharchula
# https://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 1 | saint-philippe
# https://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 1 | rikitea
# https://api.openweathermap.org/data/2.5/weather?q=santa+ana&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 1 | santa ana
# https://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 1 | bredasdorp
# https://api.openweathermap.org/data/2.5/weather?q=juneau&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 1 | juneau
# https://api.openweathermap.org/data/2.5/weather?q=vaini&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 1 | vaini
# https://api.openweathermap.org/data/2.5/weather?q=mount+isa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 1 | mount isa
# https://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 1 | jamestown
# https://api.openweathermap.org/data/2.5/weather?q=namakkal&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 1 | namakkal
# https://api.openweathermap.org/data/2.5/weather?q=barrow&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 2 | barrow
# https://api.openweathermap.org/data/2.5/weather?q=ayutinskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 2 | ayutinskiy
# https://api.openweathermap.org/data/2.5/weather?q=airai&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 2 | airai
# https://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 2 | kodiak
# https://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 2 | khatanga
# https://api.openweathermap.org/data/2.5/weather?q=ust-tsilma&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 2 | ust-tsilma
# https://api.openweathermap.org/data/2.5/weather?q=new+norfolk&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 2 | new norfolk
# https://api.openweathermap.org/data/2.5/weather?q=avarua&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 2 | avarua
# https://api.openweathermap.org/data/2.5/weather?q=riosucio&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 2 | riosucio
# https://api.openweathermap.org/data/2.5/weather?q=buncrana&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 2 | buncrana
# https://api.openweathermap.org/data/2.5/weather?q=menongue&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 2 | menongue
# https://api.openweathermap.org/data/2.5/weather?q=punta+arenas&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 2 | punta arenas
# https://api.openweathermap.org/data/2.5/weather?q=lolua&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 2 | lolua
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=balaipungut&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 2 | balaipungut
# https://api.openweathermap.org/data/2.5/weather?q=camalu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 2 | camalu
# https://api.openweathermap.org/data/2.5/weather?q=tura&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 2 | tura
# https://api.openweathermap.org/data/2.5/weather?q=grand+river+south+east&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 2 | grand river south east
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=sitka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 2 | sitka
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=meadow+lake&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 2 | meadow lake
# https://api.openweathermap.org/data/2.5/weather?q=hofn&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 2 | hofn
# https://api.openweathermap.org/data/2.5/weather?q=lagoa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 2 | lagoa
# https://api.openweathermap.org/data/2.5/weather?q=indija&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 2 | indija
# https://api.openweathermap.org/data/2.5/weather?q=heihe&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 2 | heihe
# https://api.openweathermap.org/data/2.5/weather?q=coffs+harbour&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 2 | coffs harbour
# https://api.openweathermap.org/data/2.5/weather?q=victoria&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 2 | victoria
# https://api.openweathermap.org/data/2.5/weather?q=kahului&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 2 | kahului
# https://api.openweathermap.org/data/2.5/weather?q=provideniya&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 2 | provideniya
# https://api.openweathermap.org/data/2.5/weather?q=elko&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 2 | elko
# https://api.openweathermap.org/data/2.5/weather?q=la+romana&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 2 | la romana
# https://api.openweathermap.org/data/2.5/weather?q=westport&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 2 | westport
# https://api.openweathermap.org/data/2.5/weather?q=tiarei&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 2 | tiarei
# https://api.openweathermap.org/data/2.5/weather?q=saint-pierre&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 2 | saint-pierre
# https://api.openweathermap.org/data/2.5/weather?q=vardo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 2 | vardo
# https://api.openweathermap.org/data/2.5/weather?q=ilulissat&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 2 | ilulissat
# https://api.openweathermap.org/data/2.5/weather?q=mackay&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 2 | mackay
# https://api.openweathermap.org/data/2.5/weather?q=santa+ines&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 2 | santa ines
# https://api.openweathermap.org/data/2.5/weather?q=davila&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 2 | davila
# https://api.openweathermap.org/data/2.5/weather?q=atar&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 2 | atar
# https://api.openweathermap.org/data/2.5/weather?q=thompson&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 2 | thompson
# https://api.openweathermap.org/data/2.5/weather?q=castro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 2 | castro
# https://api.openweathermap.org/data/2.5/weather?q=cabo+san+lucas&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 2 | cabo san lucas
# https://api.openweathermap.org/data/2.5/weather?q=meyungs&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 2 | meyungs
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=roald&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 2 | roald
# https://api.openweathermap.org/data/2.5/weather?q=bluff&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 2 | bluff
# https://api.openweathermap.org/data/2.5/weather?q=ribeira+grande&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 2 | ribeira grande
# https://api.openweathermap.org/data/2.5/weather?q=aklavik&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 2 | aklavik
# https://api.openweathermap.org/data/2.5/weather?q=tautira&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 2 | tautira
# https://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 2 | komsomolskiy
# https://api.openweathermap.org/data/2.5/weather?q=los+llanos+de+aridane&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 2 | los llanos de aridane
# https://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 3 | hithadhoo
# https://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 3 | tuktoyaktuk
# https://api.openweathermap.org/data/2.5/weather?q=arraial+do+cabo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 3 | arraial do cabo
# https://api.openweathermap.org/data/2.5/weather?q=bambous+virieux&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 3 | bambous virieux
# https://api.openweathermap.org/data/2.5/weather?q=moree&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 3 | moree
# https://api.openweathermap.org/data/2.5/weather?q=pisco&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 3 | pisco
# https://api.openweathermap.org/data/2.5/weather?q=rincon&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 3 | rincon
# https://api.openweathermap.org/data/2.5/weather?q=tukrah&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 3 | tukrah
# https://api.openweathermap.org/data/2.5/weather?q=laguna&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 3 | laguna
# https://api.openweathermap.org/data/2.5/weather?q=bokoro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 3 | bokoro
# https://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 3 | qaanaaq
# https://api.openweathermap.org/data/2.5/weather?q=cape+town&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 3 | cape town
# https://api.openweathermap.org/data/2.5/weather?q=alugan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 3 | alugan
# https://api.openweathermap.org/data/2.5/weather?q=belushya+guba&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=baijiantan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 3 | baijiantan
# https://api.openweathermap.org/data/2.5/weather?q=lebedyan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 3 | lebedyan
# https://api.openweathermap.org/data/2.5/weather?q=kropotkin&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 3 | kropotkin
# https://api.openweathermap.org/data/2.5/weather?q=namibe&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 3 | namibe
# https://api.openweathermap.org/data/2.5/weather?q=poltavka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 3 | poltavka
# https://api.openweathermap.org/data/2.5/weather?q=broome&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 3 | broome
# https://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 3 | butaritari
# https://api.openweathermap.org/data/2.5/weather?q=deputatskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 3 | deputatskiy
# https://api.openweathermap.org/data/2.5/weather?q=coquimbo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 3 | coquimbo
# https://api.openweathermap.org/data/2.5/weather?q=geraldton&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 3 | geraldton
# https://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 3 | kapaa
# https://api.openweathermap.org/data/2.5/weather?q=romny&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 3 | romny
# https://api.openweathermap.org/data/2.5/weather?q=mayumba&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 3 | mayumba
# https://api.openweathermap.org/data/2.5/weather?q=cayenne&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 3 | cayenne
# https://api.openweathermap.org/data/2.5/weather?q=port+hardy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 3 | port hardy
# https://api.openweathermap.org/data/2.5/weather?q=codrington&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 3 | codrington
# https://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 3 | tasiilaq
# https://api.openweathermap.org/data/2.5/weather?q=lugovoy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 3 | lugovoy
# https://api.openweathermap.org/data/2.5/weather?q=namatanai&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 3 | namatanai
# https://api.openweathermap.org/data/2.5/weather?q=hilo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 3 | hilo
# https://api.openweathermap.org/data/2.5/weather?q=ambatondrazaka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 3 | ambatondrazaka
# https://api.openweathermap.org/data/2.5/weather?q=sistranda&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 3 | sistranda
# https://api.openweathermap.org/data/2.5/weather?q=malacacheta&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 3 | malacacheta
# https://api.openweathermap.org/data/2.5/weather?q=castilho&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 3 | castilho
# https://api.openweathermap.org/data/2.5/weather?q=port+blair&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 3 | port blair
# https://api.openweathermap.org/data/2.5/weather?q=santa+isabel+do+rio+negro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 3 | santa isabel do rio negro
# https://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 3 | mar del plata
# https://api.openweathermap.org/data/2.5/weather?q=magoula&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 3 | magoula
# https://api.openweathermap.org/data/2.5/weather?q=ambovombe&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 3 | ambovombe
# https://api.openweathermap.org/data/2.5/weather?q=dikson&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 3 | dikson
# https://api.openweathermap.org/data/2.5/weather?q=salinopolis&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 3 | salinopolis
# https://api.openweathermap.org/data/2.5/weather?q=lasa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 3 | lasa
# https://api.openweathermap.org/data/2.5/weather?q=ponta+do+sol&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 3 | ponta do sol
# https://api.openweathermap.org/data/2.5/weather?q=morondava&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 3 | morondava
# https://api.openweathermap.org/data/2.5/weather?q=wembley&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 3 | wembley
# https://api.openweathermap.org/data/2.5/weather?q=chuy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 4 | chuy
# https://api.openweathermap.org/data/2.5/weather?q=raudeberg&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 4 | raudeberg
# https://api.openweathermap.org/data/2.5/weather?q=mount+gambier&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 4 | mount gambier
# https://api.openweathermap.org/data/2.5/weather?q=la+ronge&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 4 | la ronge
# https://api.openweathermap.org/data/2.5/weather?q=nome&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 4 | nome
# https://api.openweathermap.org/data/2.5/weather?q=yunjinghong&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 4 | yunjinghong
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=college&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 4 | college
# https://api.openweathermap.org/data/2.5/weather?q=amderma&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=sabang&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 4 | sabang
# https://api.openweathermap.org/data/2.5/weather?q=tupik&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 4 | tupik
# https://api.openweathermap.org/data/2.5/weather?q=khandyga&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 4 | khandyga
# https://api.openweathermap.org/data/2.5/weather?q=puerto+ayora&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 4 | puerto ayora
# https://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 4 | saleaula
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=plover&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 4 | plover
# https://api.openweathermap.org/data/2.5/weather?q=bjerkvik&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 4 | bjerkvik
# https://api.openweathermap.org/data/2.5/weather?q=caravelas&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 4 | caravelas
# https://api.openweathermap.org/data/2.5/weather?q=bardiyah&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 4 | bardiyah
# https://api.openweathermap.org/data/2.5/weather?q=sakhnovshchyna&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 4 | sakhnovshchyna
# https://api.openweathermap.org/data/2.5/weather?q=mutsamudu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 4 | mutsamudu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 4 | bengkulu
# https://api.openweathermap.org/data/2.5/weather?q=concepcion&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 4 | concepcion
# https://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 4 | chokurdakh
# https://api.openweathermap.org/data/2.5/weather?q=eirunepe&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 4 | eirunepe
# https://api.openweathermap.org/data/2.5/weather?q=maldonado&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 4 | maldonado
# https://api.openweathermap.org/data/2.5/weather?q=the+valley&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 4 | the valley
# https://api.openweathermap.org/data/2.5/weather?q=grand+centre&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 4 | grand centre
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=awbari&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 4 | awbari
# https://api.openweathermap.org/data/2.5/weather?q=inderborskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 4 | inderborskiy
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=ondorhaan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 4 | ondorhaan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=mys+shmidta&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 4 | yellowknife
# https://api.openweathermap.org/data/2.5/weather?q=merauke&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 4 | merauke
# https://api.openweathermap.org/data/2.5/weather?q=puerto+gaitan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 4 | puerto gaitan
# https://api.openweathermap.org/data/2.5/weather?q=mount+pleasant&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 4 | mount pleasant
# https://api.openweathermap.org/data/2.5/weather?q=union&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 4 | union
# https://api.openweathermap.org/data/2.5/weather?q=maghama&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 4 | maghama
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=eureka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 4 | eureka
# https://api.openweathermap.org/data/2.5/weather?q=vao&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 4 | vao
# https://api.openweathermap.org/data/2.5/weather?q=charters+towers&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 4 | charters towers
# https://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 4 | barentsburg
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=nantucket&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 4 | nantucket
# https://api.openweathermap.org/data/2.5/weather?q=zeya&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 4 | zeya
# https://api.openweathermap.org/data/2.5/weather?q=ystad&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 4 | ystad
# https://api.openweathermap.org/data/2.5/weather?q=marquette&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 4 | marquette
# https://api.openweathermap.org/data/2.5/weather?q=staryy+krym&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 4 | staryy krym
# https://api.openweathermap.org/data/2.5/weather?q=zyryanka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 4 | zyryanka
# https://api.openweathermap.org/data/2.5/weather?q=hailin&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 4 | hailin
# https://api.openweathermap.org/data/2.5/weather?q=utiroa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 4 | utiroa
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=cockburn+town&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 4 | cockburn town
# https://api.openweathermap.org/data/2.5/weather?q=sioux+lookout&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 4 | sioux lookout
# https://api.openweathermap.org/data/2.5/weather?q=pevek&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 5 | pevek
# https://api.openweathermap.org/data/2.5/weather?q=ballina&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 5 | ballina
# https://api.openweathermap.org/data/2.5/weather?q=harrisonburg&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 5 | harrisonburg
# https://api.openweathermap.org/data/2.5/weather?q=chara&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 5 | chara
# https://api.openweathermap.org/data/2.5/weather?q=praia+da+vitoria&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 5 | praia da vitoria
# https://api.openweathermap.org/data/2.5/weather?q=berlevag&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 5 | berlevag
# https://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 5 | carnarvon
# https://api.openweathermap.org/data/2.5/weather?q=saint+george&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 5 | saint george
# https://api.openweathermap.org/data/2.5/weather?q=mitsamiouli&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 5 | mitsamiouli
# https://api.openweathermap.org/data/2.5/weather?q=baykit&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 5 | baykit
# https://api.openweathermap.org/data/2.5/weather?q=talnakh&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 5 | talnakh
# https://api.openweathermap.org/data/2.5/weather?q=malwan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 5 | malwan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=alofi&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 5 | alofi
# https://api.openweathermap.org/data/2.5/weather?q=ushibuka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 5 | ushibuka
# https://api.openweathermap.org/data/2.5/weather?q=waingapu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 5 | waingapu
# https://api.openweathermap.org/data/2.5/weather?q=pangoa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 5 | pangoa
# https://api.openweathermap.org/data/2.5/weather?q=padang&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 5 | padang
# https://api.openweathermap.org/data/2.5/weather?q=port+augusta&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 5 | port augusta
# https://api.openweathermap.org/data/2.5/weather?q=pahrump&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 5 | pahrump
# https://api.openweathermap.org/data/2.5/weather?q=athabasca&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 5 | athabasca
# https://api.openweathermap.org/data/2.5/weather?q=beirut&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 5 | beirut
# https://api.openweathermap.org/data/2.5/weather?q=ancud&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 5 | ancud
# https://api.openweathermap.org/data/2.5/weather?q=payson&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 5 | payson
# https://api.openweathermap.org/data/2.5/weather?q=iquitos&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 5 | iquitos
# https://api.openweathermap.org/data/2.5/weather?q=bereda&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 5 | bereda
# https://api.openweathermap.org/data/2.5/weather?q=hambantota&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 5 | hambantota
# https://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 5 | nikolskoye
# https://api.openweathermap.org/data/2.5/weather?q=saint-georges&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 5 | saint-georges
# https://api.openweathermap.org/data/2.5/weather?q=port+elizabeth&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 5 | port elizabeth
# https://api.openweathermap.org/data/2.5/weather?q=raisen&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 5 | raisen
# https://api.openweathermap.org/data/2.5/weather?q=torbay&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 5 | torbay
# https://api.openweathermap.org/data/2.5/weather?q=sorland&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 5 | sorland
# https://api.openweathermap.org/data/2.5/weather?q=morant+bay&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 5 | morant bay
# https://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 5 | saskylakh
# https://api.openweathermap.org/data/2.5/weather?q=rawson&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 5 | rawson
# https://api.openweathermap.org/data/2.5/weather?q=tezu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 5 | tezu
# https://api.openweathermap.org/data/2.5/weather?q=faya&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 5 | faya
# https://api.openweathermap.org/data/2.5/weather?q=lokoja&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 5 | lokoja
# https://api.openweathermap.org/data/2.5/weather?q=comodoro+rivadavia&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 5 | comodoro rivadavia
# https://api.openweathermap.org/data/2.5/weather?q=ngunguru&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 5 | ngunguru
# https://api.openweathermap.org/data/2.5/weather?q=kabalo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 5 | kabalo
# https://api.openweathermap.org/data/2.5/weather?q=vila+velha&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 5 | vila velha
# https://api.openweathermap.org/data/2.5/weather?q=chapais&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 5 | chapais
# https://api.openweathermap.org/data/2.5/weather?q=batemans+bay&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 5 | batemans bay
# https://api.openweathermap.org/data/2.5/weather?q=guerrero+negro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 5 | guerrero negro
# https://api.openweathermap.org/data/2.5/weather?q=batamshinskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 5 | batamshinskiy
# https://api.openweathermap.org/data/2.5/weather?q=olafsvik&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 5 | olafsvik
# https://api.openweathermap.org/data/2.5/weather?q=mendi&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 5 | mendi
# https://api.openweathermap.org/data/2.5/weather?q=ler&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 5 | ler
# https://api.openweathermap.org/data/2.5/weather?q=constitucion&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 5 | constitucion
# https://api.openweathermap.org/data/2.5/weather?q=kant&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 6 | kant
# https://api.openweathermap.org/data/2.5/weather?q=mumford&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 6 | mumford
# https://api.openweathermap.org/data/2.5/weather?q=bethel&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 6 | bethel
# https://api.openweathermap.org/data/2.5/weather?q=rosetta&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 6 | rosetta
# https://api.openweathermap.org/data/2.5/weather?q=san+patricio&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 6 | san patricio
# https://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 6 | cherskiy
# https://api.openweathermap.org/data/2.5/weather?q=atbasar&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 6 | atbasar
# https://api.openweathermap.org/data/2.5/weather?q=west+sacramento&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 6 | west sacramento
# https://api.openweathermap.org/data/2.5/weather?q=kloulklubed&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 6 | kloulklubed
# https://api.openweathermap.org/data/2.5/weather?q=carthage&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 6 | carthage
# https://api.openweathermap.org/data/2.5/weather?q=sahbuz&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 6 | sahbuz
# https://api.openweathermap.org/data/2.5/weather?q=horta&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 6 | horta
# https://api.openweathermap.org/data/2.5/weather?q=dudinka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 6 | dudinka
# https://api.openweathermap.org/data/2.5/weather?q=asfi&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 6 | asfi
# https://api.openweathermap.org/data/2.5/weather?q=sindor&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 6 | sindor
# https://api.openweathermap.org/data/2.5/weather?q=batagay-alyta&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 6 | batagay-alyta
# https://api.openweathermap.org/data/2.5/weather?q=americus&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 6 | americus
# https://api.openweathermap.org/data/2.5/weather?q=lompoc&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 6 | lompoc
# https://api.openweathermap.org/data/2.5/weather?q=kavieng&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 6 | kavieng
# https://api.openweathermap.org/data/2.5/weather?q=sonoita&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 6 | sonoita
# https://api.openweathermap.org/data/2.5/weather?q=kutum&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 6 | kutum
# https://api.openweathermap.org/data/2.5/weather?q=kuche&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 6 | kuche
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=cap+malheureux&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 6 | cap malheureux
# https://api.openweathermap.org/data/2.5/weather?q=isangel&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 6 | isangel
# https://api.openweathermap.org/data/2.5/weather?q=aksarayskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 6 | aksarayskiy
# https://api.openweathermap.org/data/2.5/weather?q=altay&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 6 | altay
# https://api.openweathermap.org/data/2.5/weather?q=biskamzha&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 6 | biskamzha
# https://api.openweathermap.org/data/2.5/weather?q=uusikaupunki&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 6 | uusikaupunki
# https://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 6 | nizhneyansk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=katsuura&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 6 | katsuura
# https://api.openweathermap.org/data/2.5/weather?q=canberra&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 6 | canberra
# https://api.openweathermap.org/data/2.5/weather?q=teberda&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 6 | teberda
# https://api.openweathermap.org/data/2.5/weather?q=panchagarh&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 6 | panchagarh
# https://api.openweathermap.org/data/2.5/weather?q=pirgos&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 6 | pirgos
# https://api.openweathermap.org/data/2.5/weather?q=tokur&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 6 | tokur
# https://api.openweathermap.org/data/2.5/weather?q=nioro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 6 | nioro
# https://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 6 | kaitangata
# https://api.openweathermap.org/data/2.5/weather?q=mahon&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 6 | mahon
# https://api.openweathermap.org/data/2.5/weather?q=flin+flon&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 6 | flin flon
# https://api.openweathermap.org/data/2.5/weather?q=krasnogorskoye&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 6 | krasnogorskoye
# https://api.openweathermap.org/data/2.5/weather?q=sikonge&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 6 | sikonge
# https://api.openweathermap.org/data/2.5/weather?q=kiunga&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 6 | kiunga
# https://api.openweathermap.org/data/2.5/weather?q=kudahuvadhoo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 6 | kudahuvadhoo
# https://api.openweathermap.org/data/2.5/weather?q=lavrentiya&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 6 | lavrentiya
# https://api.openweathermap.org/data/2.5/weather?q=sinop&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 6 | sinop
# https://api.openweathermap.org/data/2.5/weather?q=yola&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 6 | yola
# https://api.openweathermap.org/data/2.5/weather?q=anadyr&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 6 | anadyr
# https://api.openweathermap.org/data/2.5/weather?q=tsihombe&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 6 | tsihombe
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=suez&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 6 | suez
# https://api.openweathermap.org/data/2.5/weather?q=iqaluit&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 6 | iqaluit
# https://api.openweathermap.org/data/2.5/weather?q=sambava&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 7 | sambava
# https://api.openweathermap.org/data/2.5/weather?q=neuquen&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 7 | neuquen
# https://api.openweathermap.org/data/2.5/weather?q=vila+franca+do+campo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 7 | vila franca do campo
# https://api.openweathermap.org/data/2.5/weather?q=half+moon+bay&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 7 | half moon bay
# https://api.openweathermap.org/data/2.5/weather?q=yar-sale&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 7 | yar-sale
# https://api.openweathermap.org/data/2.5/weather?q=tampere&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# ...
# Processing Record 45 of Set 13 | ambulu
# https://api.openweathermap.org/data/2.5/weather?q=urumqi&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 13 | urumqi
# https://api.openweathermap.org/data/2.5/weather?q=lasko&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 13 | lasko
# https://api.openweathermap.org/data/2.5/weather?q=ambodifototra&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 13 | ambodifototra
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=caucaia&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 13 | caucaia
# https://api.openweathermap.org/data/2.5/weather?q=doba&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 13 | doba
# https://api.openweathermap.org/data/2.5/weather?q=addi+ugri&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 14 | addi ugri
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=banda+aceh&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 14 | banda aceh
# https://api.openweathermap.org/data/2.5/weather?q=lanxi&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 14 | lanxi
# https://api.openweathermap.org/data/2.5/weather?q=pimentel&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 14 | pimentel
# https://api.openweathermap.org/data/2.5/weather?q=tongchuan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 14 | tongchuan
# https://api.openweathermap.org/data/2.5/weather?q=takaungu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 14 | takaungu
# https://api.openweathermap.org/data/2.5/weather?q=mullaitivu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 14 | mullaitivu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=khonsa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 14 | khonsa
# https://api.openweathermap.org/data/2.5/weather?q=dzhebariki-khaya&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 14 | dzhebariki-khaya
# https://api.openweathermap.org/data/2.5/weather?q=pochutla&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 14 | pochutla
# https://api.openweathermap.org/data/2.5/weather?q=morales&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 14 | morales
# https://api.openweathermap.org/data/2.5/weather?q=makueni&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 14 | makueni
# https://api.openweathermap.org/data/2.5/weather?q=tabou&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 14 | tabou
# https://api.openweathermap.org/data/2.5/weather?q=kavaratti&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 14 | kavaratti
# https://api.openweathermap.org/data/2.5/weather?q=visby&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 14 | visby
# https://api.openweathermap.org/data/2.5/weather?q=paracuru&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 14 | paracuru
# https://api.openweathermap.org/data/2.5/weather?q=lulea&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 14 | lulea
# https://api.openweathermap.org/data/2.5/weather?q=iskateley&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 14 | iskateley
# https://api.openweathermap.org/data/2.5/weather?q=kadaya&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 14 | kadaya
# https://api.openweathermap.org/data/2.5/weather?q=saint+anthony&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 14 | saint anthony
# https://api.openweathermap.org/data/2.5/weather?q=okhotsk&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 14 | okhotsk
# https://api.openweathermap.org/data/2.5/weather?q=port+moresby&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 14 | port moresby
# https://api.openweathermap.org/data/2.5/weather?q=mehamn&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 14 | mehamn
# https://api.openweathermap.org/data/2.5/weather?q=kailua&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 14 | kailua
# https://api.openweathermap.org/data/2.5/weather?q=ha+tinh&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 14 | ha tinh
# https://api.openweathermap.org/data/2.5/weather?q=bara&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 14 | bara
# https://api.openweathermap.org/data/2.5/weather?q=ingham&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 14 | ingham
# https://api.openweathermap.org/data/2.5/weather?q=fuente+de+oro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 14 | fuente de oro
# https://api.openweathermap.org/data/2.5/weather?q=san+cristobal&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 14 | san cristobal
# https://api.openweathermap.org/data/2.5/weather?q=strezhevoy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 14 | strezhevoy
# https://api.openweathermap.org/data/2.5/weather?q=ust-ordynskiy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 14 | ust-ordynskiy
# https://api.openweathermap.org/data/2.5/weather?q=dauphin&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 14 | dauphin
# https://api.openweathermap.org/data/2.5/weather?q=pansoy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 14 | pansoy
# https://api.openweathermap.org/data/2.5/weather?q=torrington&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 14 | torrington
# https://api.openweathermap.org/data/2.5/weather?q=maarianhamina&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 14 | maarianhamina
# https://api.openweathermap.org/data/2.5/weather?q=neiafu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 14 | neiafu
# https://api.openweathermap.org/data/2.5/weather?q=mogadishu&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 14 | mogadishu
# https://api.openweathermap.org/data/2.5/weather?q=baloda+bazar&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 14 | baloda bazar
# https://api.openweathermap.org/data/2.5/weather?q=la+rioja&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 14 | la rioja
# https://api.openweathermap.org/data/2.5/weather?q=kieta&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 14 | kieta
# https://api.openweathermap.org/data/2.5/weather?q=snasa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 14 | snasa
# https://api.openweathermap.org/data/2.5/weather?q=port+macquarie&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 14 | port macquarie
# https://api.openweathermap.org/data/2.5/weather?q=belaya+gora&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 14 | belaya gora
# https://api.openweathermap.org/data/2.5/weather?q=ijaki&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 14 | ijaki
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tecoanapa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 14 | tecoanapa
# https://api.openweathermap.org/data/2.5/weather?q=gobabis&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 46 of Set 14 | gobabis
# https://api.openweathermap.org/data/2.5/weather?q=muroto&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 47 of Set 14 | muroto
# https://api.openweathermap.org/data/2.5/weather?q=mufulira&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 48 of Set 14 | mufulira
# https://api.openweathermap.org/data/2.5/weather?q=mana&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 49 of Set 14 | mana
# https://api.openweathermap.org/data/2.5/weather?q=turka&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 50 of Set 14 | turka
# https://api.openweathermap.org/data/2.5/weather?q=kegayli&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 1 of Set 15 | kegayli
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=trincomalee&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 2 of Set 15 | trincomalee
# https://api.openweathermap.org/data/2.5/weather?q=olinda&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 3 of Set 15 | olinda
# https://api.openweathermap.org/data/2.5/weather?q=mancio+lima&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 4 of Set 15 | mancio lima
# https://api.openweathermap.org/data/2.5/weather?q=kirakira&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 5 of Set 15 | kirakira
# https://api.openweathermap.org/data/2.5/weather?q=harnosand&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 6 of Set 15 | harnosand
# https://api.openweathermap.org/data/2.5/weather?q=macaboboni&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 7 of Set 15 | macaboboni
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tongsa&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 8 of Set 15 | tongsa
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=adrar&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 9 of Set 15 | adrar
# https://api.openweathermap.org/data/2.5/weather?q=verkhnevilyuysk&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 10 of Set 15 | verkhnevilyuysk
# https://api.openweathermap.org/data/2.5/weather?q=aljezur&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 11 of Set 15 | aljezur
# https://api.openweathermap.org/data/2.5/weather?q=khani&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 12 of Set 15 | khani
# https://api.openweathermap.org/data/2.5/weather?q=touros&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 13 of Set 15 | touros
# https://api.openweathermap.org/data/2.5/weather?q=alenquer&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 14 of Set 15 | alenquer
# https://api.openweathermap.org/data/2.5/weather?q=metro&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 15 of Set 15 | metro
# https://api.openweathermap.org/data/2.5/weather?q=camocim&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 16 of Set 15 | camocim
# https://api.openweathermap.org/data/2.5/weather?q=lokosovo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 17 of Set 15 | lokosovo
# https://api.openweathermap.org/data/2.5/weather?q=antsohihy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 18 of Set 15 | antsohihy
# https://api.openweathermap.org/data/2.5/weather?q=wageningen&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 19 of Set 15 | wageningen
# https://api.openweathermap.org/data/2.5/weather?q=buala&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 20 of Set 15 | buala
# https://api.openweathermap.org/data/2.5/weather?q=manokwari&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 21 of Set 15 | manokwari
# https://api.openweathermap.org/data/2.5/weather?q=cumaribo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 22 of Set 15 | cumaribo
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tommot&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 23 of Set 15 | tommot
# https://api.openweathermap.org/data/2.5/weather?q=shelui&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 24 of Set 15 | shelui
# https://api.openweathermap.org/data/2.5/weather?q=yulara&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 25 of Set 15 | yulara
# https://api.openweathermap.org/data/2.5/weather?q=bolshoy+tsaryn&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 26 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=skjervoy&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 27 of Set 15 | skjervoy
# https://api.openweathermap.org/data/2.5/weather?q=barquisimeto&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 28 of Set 15 | barquisimeto
# https://api.openweathermap.org/data/2.5/weather?q=mincivan&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 29 of Set 15 | mincivan
# https://api.openweathermap.org/data/2.5/weather?q=conde&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 30 of Set 15 | conde
# https://api.openweathermap.org/data/2.5/weather?q=guanica&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 31 of Set 15 | guanica
# https://api.openweathermap.org/data/2.5/weather?q=kargasok&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 32 of Set 15 | kargasok
# https://api.openweathermap.org/data/2.5/weather?q=la+libertad&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 33 of Set 15 | la libertad
# https://api.openweathermap.org/data/2.5/weather?q=timberlake&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 34 of Set 15 | timberlake
# https://api.openweathermap.org/data/2.5/weather?q=zachagansk&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 35 of Set 15 | zachagansk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=kourou&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 36 of Set 15 | kourou
# https://api.openweathermap.org/data/2.5/weather?q=biharamulo&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 37 of Set 15 | biharamulo
# https://api.openweathermap.org/data/2.5/weather?q=moindou&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 38 of Set 15 | moindou
# https://api.openweathermap.org/data/2.5/weather?q=sirnak&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 39 of Set 15 | sirnak
# https://api.openweathermap.org/data/2.5/weather?q=hanmer+springs&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 40 of Set 15 | hanmer springs
# https://api.openweathermap.org/data/2.5/weather?q=ayolas&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 41 of Set 15 | ayolas
# https://api.openweathermap.org/data/2.5/weather?q=villa+carlos+paz&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 42 of Set 15 | villa carlos paz
# https://api.openweathermap.org/data/2.5/weather?q=anacortes&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 43 of Set 15 | anacortes
# https://api.openweathermap.org/data/2.5/weather?q=tucurui&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 44 of Set 15 | tucurui
# https://api.openweathermap.org/data/2.5/weather?q=safford&appid=1fef1c9f6a83d470811f59873f9104f8&units=imperial
# Processing Record 45 of Set 15 | safford
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Labuhan  -6.8844  112.2051     79.61        82          71
# 1      Mahebourg -20.4081   57.7000     75.49        73          75
# 2            Wum   6.3833   10.0667     66.54        91         100
# 3         Albany  42.6001  -73.9662     63.27        93          95
# 4            Sur  22.5667   59.5289     84.97        37           0
# 5       Hermanus -34.4187   19.2345     66.79        46          90
# 6  Berdigestyakh  62.0989  126.6992     37.18        80         100
# 7         Manono  -7.3000   27.4167     72.03        67          86
# 8        Dunedin -45.8742  170.5036     60.80        70          98
# 9      Busselton -33.6500  115.3333     58.71        65          62
#
#    Wind Speed      Description Country                 Date
# 0        6.22    broken clouds      ID  2022-05-16 23:32:30
# 1       11.50    broken clouds      MU  2022-05-16 23:32:31
# 2        2.26  overcast clouds      CM  2022-05-16 23:32:32
# 3       10.96  overcast clouds      US  2022-05-16 23:29:33
# 4        5.57        clear sky      OM  2022-05-16 23:32:33
# 5        2.66  overcast clouds      ZA  2022-05-16 23:32:33
# 6        3.58  overcast clouds      RU  2022-05-16 23:32:35
# 7        3.04  overcast clouds      CD  2022-05-16 23:32:35
# 8        5.99  overcast clouds      NZ  2022-05-16 23:32:36
# 9       10.45    broken clouds      AU  2022-05-16 23:32:37

# %%
# Create the output file (CSV)
output_data_file = 'WeatherPy_Database.csv'
# Export city_data into CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
